# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('mi_base_de_datos.sqlite')

cursor = conn.cursor()

# %%
# Atracciones

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Rápidos ACME',
                    'Adolescentes y Adultos',
                    16,
                    '-',
                    110,
                    'Los Rápidos ACME son, sencillamente, ¡desternillantes! Forman una increíble atracción acuática ubicada en Cartoon Village, el lugar perfecto para tener la sensación de estar viviendo dentro de un capítulo de los alocados y traviesos Looney Tunes.',
                    'B9',
                    '02', 
                    '029')''')


cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Cataratas Salvajes',
                    'Adolescentes y Adultos',
                    16,
                    '-',
                    110,
                    'Siéntate en la primera fila (o en la última) y empápate de agua, la caída de esta atracción se produce a una gran altura, y el oleaje que provoca es simplemente espectacular.',
                    'B8',
                    '02', 
                    '028')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Río Bravo',
                    'Todos los públicos',
                    6,
                    '-',
                    100,
                    'Río Bravo es un western que el gran Howard Hawks dirigió en 1959, con John Wayne como protagonista. Y es -también-, una de las atracciones acuáticas ineludibles de Old West Territory, en Parque Warner.',
                    'B7',
                    '02', 
                    '027')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Correcaminos Bip Bip',
                    'Niños y Familias',
                    9,
                    '-',
                    100,
                    'Sube con tus pequeños e intenta así ayudar al incansable Wile E. Coyote en su interminable carrera para alcanzar al escurridizo Correcaminos. El velocísimo pájaro corre desenfrenadamente por el desierto de Parque Warner: ven y persíguelo con tu familia.',
                    'B6',
                    '02', 
                    '026')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Coaster Express',
                    'Adolescentes y Adultos',
                    16,
                    '-',
                    121,
                    'Valles y cañones conforman el trazado desértico de Coaster-Express, la ‘roller coaster’ tradicional que podemos encontrar en Parque Warner Madrid.',
                    'B5',
                    '02', 
                    '025')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Superman Atracción de Acero',
                    'Adolescentes y Adultos',
                    16,
                    '-',
                    132,
                    'Esta atracción de Parque Warner recrea la ciudad de Metrópolis, así como la entrada del famoso periódico de la urbe, el Daily Planet.',
                    'B4',
                    '02', 
                    '024')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Batman Gotham City',
                    'Adolescentes y Adultos',
                    16,
                    '-',
                    130,
                    'La única manera de escapar de la ciudad es a través de esta montaña rusa multilaunch, única en Europa.',
                    'B3',
                    '02', 
                    '023')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Lindo Gatito',
                    'Familiar',
                    6,
                    '-',
                    110,
                    '¿Te ha parecido ver a un lindo gatito? Monta entonces en esta atracción mecánica, pensada para los visitantes pequeños, para que experimenten el gusanillo de volar al tiempo que persiguen al canario más popular de la factoría Warner.',
                    'B2',
                    '02', 
                    '022')''') 

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Coyote Explosivo',
                    'Familiar',
                    9,
                    '-',
                    0.92,
                    'Wile E. Coyote, inasequible al desaliento, anda detrás del Correcaminos, 
                    y en esta ocasión ha puesto en marcha un último invento sobre el que ha depositado sus esperanzas',
                    'B1',
                    '02', 
                    '021')''')

# %%
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('023',
                    "Batman Gotham City Escape",
                    'Platos_Tipicos',
                    "La Casa de Batman",
                    "te sentirás el protagonista de tu película favorita. Seas héroe o villano, descubre todas las atracciones",
                    "12:00",
                    '1500')''')

cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('021',
                    "Correcaminos",
                    'Platos_Tipicos',
                    "Un campo lleno de trampas a evitar",
                    "Descubre los mejores lugares para correr del coyote",
                    "10:00",
                    '300')''')

cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('025',
                    "Old West Territory",
                    'Platos_Tipicos',
                    "Lugares del Viejo Oeste",
                    "Atrevete a ser un Vaquero montado en el caballo más veloz escapando de los apaches",
                    "10:00",
                    '6000')''')

# %%
cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel NH Hotel Group",
                    75,
                    "4 estrellas",
                    "125 Habitaciones para familias",
                    "Hotel Moderno")''')

cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel Looney Tunes",
                    55,
                    "3 estrellas",
                    "100 Habitaciones para todos los públicos",
                    "Hotel ambientado con los personajes mas característicos del mundo Warner")''')

cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel Gotham",
                    120,
                    "5 estrellas",
                    "50 Habitaciones",
                    "Hotel ambientado en la casa de Bruce Wayne")''')

# %%
df = pd.read_sql_query('SELECT * FROM zonas ', conn)
df
# Out:
#   Codigo_Zona               Ambientacion  Platos_Tipicos  \
# 0         031                    Egipcia  Platos_Tipicos
# 1         032                     Romano  Platos_Tipicos
# 2         033                  Las islas  Platos_Tipicos
# 3         034                      Ibera  Platos_Tipicos
# 4         035                     Griega  Platos_Tipicos
# 5         023  Batman Gotham City Escape  Platos_Tipicos
# 6         021               Correcaminos  Platos_Tipicos
# 7         025         Old West Territory  Platos_Tipicos
#
#                          Espectaculos  \
# 0                  El sueño de Egipto
# 1           Espartaco, honor y coraje
# 2                  El caballo español
# 3                         Mitic dance
# 4              La magia de los dioses
# 5                   La Casa de Batman
# 6  Un campo lleno de trampas a evitar
# 7             Lugares del Viejo Oeste
#
#                                          Descripcion Horario  Afluencia_Media
# 0  La vida de la joven Samira está a punto de cam...      22  Afluencia_Media
# 1  ¿Quieres descubrir el origen del mito que hizo...      35  Afluencia_Media
# 2  La pasión del elenco de bailaoras y la belleza...       8  Afluencia_Media
# 3  La canción que nunca pasa de moda cantada y ba...      10  Afluencia_Media
# 4  El gran Zeus ha perdido su fuerza después de q...      20  Afluencia_Media
# 5  te sentirás el protagonista de tu película fav...   12:00             1500
# 6  Descubre los mejores lugares para correr del c...   10:00              300
# 7  Atrevete a ser un Vaquero montado en el caball...   10:00             6000

# %%
conn.commit()
df = pd.read_sql_query('SELECT * FROM atracciones ', conn)
df
# Out:
#                          Nombre                    Tipo  Categoria_edad  \
# 0          Puerto de Alejandria                Familiar               2
# 1            Cataratas del Nilo             Emocionante               6
# 2                      Akuatiti                Infantil               3
# 3                      Infinito                Familiar               6
# 4                       Tornado             Emocionante              12
# 5                   Ayquesustus                Infantil               5
# 6                      Rotundus                Infantil               3
# 7                       Inferno             Emocionante              14
# 8            El vuelo del Fenix             Emocionante              10
# 9                        Mithos                Familiar               3
# 10         La colera de Aquiles             Emocionante              14
# 11             Rapidos de Argos                Familiar               0
# 12                      Arietes                Familiar               6
# 13                       Jabato                Infantil               4
# 14                   Tentaculus                Infantil               0
# 15                    Clepsidra                Infantil               0
# 16                     Synkopin                Infantil               6
# 17                       Anilus                Infantil               0
# 18   El laberinto del minotauro                Familiar               4
# 19                     Titanide             Emocionante              14
# 20            Templo de Kinetos                Familiar               6
# 21                      Synkope             Emocionante              10
# 22           La furia de Triton             Emocionante               6
# 23                   Los Icaros                Familiar               6
# 24                   Alucinakis                Infantil               5
# 25                 Rápidos ACME  Adolescentes y Adultos              16
# 26           Cataratas Salvajes  Adolescentes y Adultos              16
# 27                    Río Bravo      Todos los públicos               6
# 28         Correcaminos Bip Bip        Niños y Familias               9
# 29              Coaster Express  Adolescentes y Adultos              16
# 30  Superman Atracción de Acero  Adolescentes y Adultos              16
# 31           Batman Gotham City  Adolescentes y Adultos              16
# 32                 Lindo Gatito                Familiar               6
# 33             Coyote Explosivo                Familiar               9
#
#    Longitud_Atraccion  Altura_Minima  \
# 0                   -           0.92
# 1                30.0           1.20
# 2                   -           0.92
# 3               100.0           0.92
# 4                80.0           1.30
# 5                 6.0           0.92
# 6                   -           0.92
# 7                   -           1.40
# 8                54.0           1.30
# 9                54.0           0.92
# 10                  -           1.20
# 11                  -           1.20
# 12                  -           1.20
# 13                  -           0.92
# 14                  -           0.92
# 15                  -           0.92
# 16                  -           1.10
# 17                  -           0.92
# 18                  -           1.10
# 19                  -           1.30
# 20                  -           1.10
# 21                  -           1.40
# 22                  -           0.92
# 23                  -           1.20
# 24                  -           0.92
# 25                  -         110.00
# 26                  -         110.00
# 27                  -         100.00
# 28                  -         100.00
# 29                  -         121.00
# 30                  -         132.00
# 31                  -         130.00
# 32                  -         110.00
# 33                  -           0.92
#
#                                           Descripcion codigo_atraccion  \
# 0   Disfruta de las vistas desde las naves Seker y...               A1
# 1   Deslízate por una montaña rusa de agua en los ...               A2
# 2   Los más pequeños también pueden disfrutar de u...               A3
# 3   Ofrece unas vistas privilegiadas de Terra Míti...               A4
# 4   ¿Te atreves a desafiar una imponente torre de ...              A13
# 5   No hay excusa para que los más pequeños disfru...              A15
# 6   Disfruta de las vistas a la plaza romana con e...              A16
# 7   ¿Te crees capaz de estar boca abajo, boca arri...              A17
# 8   ¿Estás preparado para experimentar una verdade...              A18
# 9   Un brillante carrusel que llama la atención po...              A20
# 10  Te elevas hacia el cielo mientras te balanceas...              A21
# 11  Cuando aprieta el calor en el Parque sienta de...              A22
# 12  La ambientación de los autos de choque que la ...              A23
# 13  La hermana pequeña de los Arietes es una atrac...              A24
# 14  Unas antorchas de refinado diseño sirven de ve...              A25
# 15  Unas antorchas de refinado diseño sirven de ve...              A26
# 16  El hermano pequeño de la vertiginosa atracción...              A28
# 17  Los niños disfrutarán de una emocionante trave...              A29
# 18  ¡Enfréntate a las mismas pruebas que Teseo y d...               A5
# 19  Una montaña rusa invertida que alcanza la velo...               A6
# 20  Una gran escultura de Zeus preside el Templo d...               A7
# 21  Imagina un disco girando a 90km/h a una altura...               A8
# 22  Sin duda, ésta es la atracción más buscada en ...               A9
# 23  Disfruta de las vistas del parque y las playas...              A10
# 24  Con esta atracción, los más pequeños también p...              A11
# 25  Los Rápidos ACME son, sencillamente, ¡desterni...               B9
# 26  Siéntate en la primera fila (o en la última) y...               B8
# 27  Río Bravo es un western que el gran Howard Haw...               B7
# 28  Sube con tus pequeños e intenta así ayudar al ...               B6
# 29  Valles y cañones conforman el trazado desértic...               B5
# 30  Esta atracción de Parque Warner recrea la ciud...               B4
# 31  La única manera de escapar de la ciudad es a t...               B3
# 32  ¿Te ha parecido ver a un lindo gatito? Monta e...               B2
# 33  Wile E. Coyote, inasequible al desaliento, and...               B1
#
#     codigo_parque  codigo_zona
# 0               3           31
# 1               3           31
# 2               3           31
# 3               3           31
# 4               3           32
# 5               3           32
# 6               3           32
# 7               3           32
# 8               3           32
# 9               3           33
# 10              3           33
# 11              3           33
# 12              3           34
# 13              3           34
# 14              3           34
# 15              3           34
# 16              3           34
# 17              3           34
# 18              3           35
# 19              3           35
# 20              3           35
# 21              3           35
# 22              3           35
# 23              3           35
# 24              3           35
# 25              2           29
# 26              2           28
# 27              2           27
# 28              2           26
# 29              2           25
# 30              2           24
# 31              2           23
# 32              2           22
# 33              2           21

# %%
df = pd.read_sql_query('SELECT * FROM alojamiento', conn)
df
# Out:
#                  Nombre  Precio    Categoria  \
# 0  Hotel NH Hotel Group    75.0  4 estrellas
# 1    Hotel Looney Tunes    55.0  3 estrellas
# 2          Hotel Gotham   120.0  5 estrellas
#
#                                   Servicios  \
# 0            125 Habitaciones para familias
# 1  100 Habitaciones para todos los públicos
# 2                           50 Habitaciones
#
#                                         Ambientacion
# 0                                      Hotel Moderno
# 1  Hotel ambientado con los personajes mas caract...
# 2         Hotel ambientado en la casa de Bruce Wayne

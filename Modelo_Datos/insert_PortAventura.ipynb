# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('mi_base_de_datos.sqlite')

cursor = conn.cursor()

# %%
# PARQUE - PortAventura 01
cursor.execute('''INSERT OR IGNORE INTO Parque_atracciones 
                  VALUES ('Port Aventura', 'Avinguda Alcalde Pere Molas', 'Salou', 'Tarragona', 51000, '01')''')

# %%
# ATRACCIONES - PortAventura 01
# Far West '01'1

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Uncharted',
                    'Emocionante',
                    13,
                    130,
                    'Uncharted: El Enigma de Penitence es la búsqueda del tesoro más emocionante del lejano Oeste. 
                    Toneladas de oro azteca, mil trampas que lo protegen y muchos cazatesoros luchando por conseguirlo en una dark ride llena de emoción y diversión.',
                    'C1',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Silver River Flume',
                    'Emocionante',
                    13,
                    140,
                    'En el centro del poblado de Penitence, en el área de Far West de PortAventura, se encuentra el enorme aserradero de la compañía regional The Silver River Milling & Lumber Co.
                    Aquí, los troncos talados se convierten en las tablas más rectas del mundo. Móntate en uno de estos troncos, deja que la corriente te arrastre y vive la adrenalina en cada una de las bajadas de los canales.
                    ¡La diversión está asegurada! Cada caída será más fuerte que la anterior en este peculiar y refrescante viaje por el famoso aserradero de Penitence.
                    ¡Ármate de valor y descubre el recorrido fluvial de Silver River Flume!',
                    'C2',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Stampida',
                    'Emocionante',
                    10,
                    120,
                    'A las afueras del pueblo de Penitence, en PortAventura World, se encuentra la espectacular Stampida, una montaña rusa de madera construida por las familias Connery y Cranberry.
                    Cada familia está representada por una carretilla roja y azul respectivamente. Ambas familias se batían en duelo constante por conseguir nuevos terrenos.
                    Esta atracción de un kilómetro de subidas y bajadas te dejará sin aliento mientras viajas a 70 km/h. El suelo empieza a temblar y una nube de polvo se alza a lo lejos… 
                    ¡Corre todo lo que puedas para llegar primero!',
                    'C3',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Tomahawk',
                    'Infantil',
                    8,
                    105,
                    'Esta historia nos ha servido para crear una montaña rusa infantil con trepidantes subidas y bajadas que pondrá a prueba el valor de todos los que se atrevan a desafiarla. 
                    Su rápido recorrido se entrelaza con el de Stampida, lo que le otorga sensación de más velocidad. 
                    Si te atreves a montarte, ¡aguanta hasta la última bajada y posa para la foto que podrás llevarte de recuerdo!',
                    'C4',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('VolPaiute',
                    'Moderada',
                    13,
                    140,
                    'Desafía al gran jefe de la tribu en un duro combate con el ritual de la danza giratoria. En esta batalla, tú decides a qué velocidad quieres girar, pero no la altura a la que subes… 
                    ¿Serás capaz de seguir dando vueltas sin parar viendo como desciende la plataforma? ¡En el momento álgido, la plataforma se ladeará hasta llegar casi al límite horizontal!
                    ¡Sé el más valiente y prueba la atracción giratoria más impactante de PortAventura!',
                    'C5',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Wild Buffalos',
                    'Moderada',
                    13,
                    140,
                    'En esta atracción tendrás que conducir un desbocado búfalo por una inmensa pista situada en el interior de un edificio que reproduce de manera exacta los edificios base que se construían en las excavaciones de oro de los Estados Unidos de América.
                    Elige el búfalo más bravo y demuestra tus habilidades mientras escapas de la embestida del resto de animales enloquecidos. ¡Tendrás que ser muy audaz para no chocar con el resto de los vaqueros! 
                    Un verdadero juego de estrategia en el que mayores y pequeños os lo pasaréis en grande mientras tratáis de salir de este típico rodeo americano en forma de autos de choque.', 
                    'C6',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Buffalo Rodeo',
                    'Infantil',
                    0,
                    0,
                    'En la atracción Buffalo Rodeo de Far West de PortAventura aprenderás a dominar el arte del rodeo en una auténtica excavación de oro americana donde solo existe una ley: la del más fuerte.', 
                    'C7',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Crazy Barrels',
                    'Moderada',
                    10,
                    130,
                    'Estos locos barriles girarán muy rápido para que sientas la adrenalina y te lo pases genial. Cuando suene la sirena, agárrate fuerte porque empezará un espectáculo en el que darás vueltas muy deprisa mientras disfrutas con los amigos. 
                    ¡No querrás que se acabe nunca! Pero no te preocupes, podrás montarte todas las veces que quieras y cada vez será más divertida que la anterior.',
                    'C8',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Grand Canyon Rapids',
                    'Moderada',
                    10,
                    130,
                    'Súbete a una de las embarciones con capacidad máxima de nueve personas y disfruta de esta atracción del mundo de Far West con toda la familia. 
                    Enfréntate a la fuerza del río mientras los pistoleros te vigilan desde sus escondites para refrescarte con sus pistolas de agua.',
                    'C9',
                    '01', 
                    '011')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Laberinto Blacksmith',
                    'Infantil',
                    0,
                    100,
                    'Atrévete a entrar en este viejo y destartalado laberinto, y ayuda al conocido ladronzuelo a mantener su escondite forjado en una antigua herrería reconvertida en restaurante. 
                    Mientras tanto, desentraña todos los misterios y encuentra la salida del Laberinto BlackSmith para librarte de las maléficas sorpresas que te aguardan en su interior.',
                    'C9',
                    '01', 
                    '011')''')

# China '01'2
cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Shambhala',
                    'Emocionante',
                    13,
                    140,
                    'Esta montaña rusa es la más alta y con la caída más larga de PortAventura Park, y está dentro del grupo de las hypercoasters, que se caracterizan por su gran tamaño y altura. 
                    Sus cinco camelbacks (elevaciones durante el recorrido) harán que tengas la sensación de haber perdido contacto con el asiento y vas a querer repetir nada más bajar. ¿Estás dispuesto a vivir la experiencia de Shambhala?',
                    'C10',
                    '01', 
                    '012')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Dragon Khan',
                    'Emocionante',
                    13,
                    140,
                    'La atracción Dragon Khan de PortAventura empieza con una gran bajada, seguida de ocho loopings que recorrerás en 69 segundos a una velocidad de hasta 110 km/h. 
                    Su imponente apariencia lo ha convertido en uno de los emblemas de PortAventura y de todos los parques temáticos de España, 
                    ya que nunca se había visto nada parecido hasta la apertura del parque en 1995. ¡Ven a comprobarlo tú mismo!',
                    'C11',
                    '01', 
                    '012')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Cobra Imperial',
                    'Moderada',
                    10,
                    130,
                    'La atracción Cobra Imperial está pensada para que los más pequeños se dejen llevar por la velocidad y suelten toda su adrenalina acompañados de quienes ellos prefieran.
                     ¿Estáis todos preparados para subiros?',
                    'C12',
                    '01', 
                    '012')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Tea Cups',
                    'Moderada',
                    10,
                    130,
                    'Tu familia y tú podréis subiros en la misma taza de porcelana gigante y tomar el control del volante que encontraréis en el centro.
                     Daréis vueltas sin parar. No te preocupes, estas tazas no son nada frágiles y la diversión está totalmente garantizada para pequeños y mayores.
                    ¡Compite con el resto de tazas para ver quién da más vueltas!',
                    'C13',
                    '01', 
                    '012')''')

#Mediterrània '01'3

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Furius Baco',
                    'Emocionante',
                    12,
                    140,
                    'Esta increíble atracción pone a prueba a los más valientes acelerando de 0 a 135 km/h en tan solo 3 segundos. 
                    En su vertiginoso recorrido, se desliza casi a ras de suelo, atraviesa zanjas y túneles, e incluso roza el agua del lago de Mediterrània. 
                    Furius Baco es, sin duda, una de las atracciones en la que más adrenalina se libera. En sus 850 metros de recorrido, la potencia, la velocidad y la aceleración serán los protagonistas.',
                    'C14',
                    '01', 
                    '013')''')

#SésamoAventura '01'4

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Street Mission',
                    'Infantil',
                    8,
                    120,
                    'Siéntete todo un detective junto a Coco en esta aventura llena de retos. ¿Serás capaz de ayudarle a resolver su misión secreta?',
                    'C15',
                    '01', 
                    '014')''')


cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Tami Tami',
                    'Infantil',
                    8,
                    130,
                    'Pasa el impresionante pórtico de entrada a este nuevo mundo de PortAventura World y escucha la velocidad a la que viaja la intrépida Tami Tami. 
                    Es la única montaña rusa infantil del parque y está pensada para que pequeños y mayores sientan la adrenalina de sus subidas y bajadas.',
                    'C16',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Waikiki',
                    'Infantil',
                    0,
                    0,
                    'Las sillas voladoras de Waikiki de PortAventura empezarán a subir y a girar más y más. Los más pequeños tendrán la sensación de que pueden tocar las nubes encima del parque temático.',
                    'C17',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Coco Piloto',
                    'Infantil',
                    8,
                    130,
                    'Elige tu avión favorito entre todos los que ha pintado Coco y siéntete como un auténtico piloto mientras saludas a la familia desde la cabina y observas las blancas nubes, 
                    el mundo de SésamoAventura y todo el esplendor del parque temático.',
                    'C18',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('El Árbol Mágico',
                    'Infantil',
                    0,
                    0,
                    'Además de ser un árbol, tiene una gran escalinata que lo convierte en el mirador más privilegiado del área. 
                    Si quieres, puedes entrar y hacerte una foto con unas simpáticas ardillas que te están esperando sentadas encima de unas grandes setas de colores vivos',
                    'C19',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('El Salto de Blas',
                    'Infantil',
                    8,
                    130,
                    'Este simpático personaje de Sesame Street ha construido dos torres amarillas en el área temática infantil del parque para que los pequeños puedan experimentar una sensación como la de los mayores; con una diferencia, en esta atracción tú decides. 
                    Sube tirando de una cuerda y cuando creas que ya has llegado a la altura suficiente… ¡déjate caer! 
                    Puedes dejarte caer las veces que quieras mientras la atracción va dando vueltas. Cuando pare, tu turno habrá terminado, así que no lo dudes y sube arriba del todo y experimenta las sensaciones de una caída libre.',
                    'C20',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Kiddie Dragons',
                    'Infantil',
                    0,
                    0,
                    'Un paseo agradable y divertido en el que llegarás a creer que flotas por el cielo de PortAventura World con estos divertidos dragones orientales. ¡Ideal para que los más pequeños se lo pasen en grande!',
                    'C21',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('La Granja de Elmo',
                    'Infantil',
                    0,
                    120,
                    'Descubre cuáles son los animales favoritos de Elmo desde un divertido tractor decorado a todo color mientras tú y toda tu familia os quedáis fascinados de la alegría que se vive en este rincón de PortAventura',
                    'C22',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Mariposas Saltarinas',
                    'Infantil',
                    8,
                    120,
                    'Busca un acompañante y súbete en las Mariposas Saltarinas. Una vez te hayas montado, empieza a pedalear con fuerza para que las mariposas empiecen a volar. 
                    Estas mariposas utilizan la fuerza del pedaleo para subir hasta el cielo y disfrutar tanto como tú en esta atracción de PortAventura.',
                    'C23',
                    '01', 
                    '014')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Magic Fish',
                    'Infantil',
                    8,
                    140,
                    'Sube a un barco mágico que te permitirá llegar a la zona donde podrás subirte en uno de los peces. Conduce tu Magic Fish, que irá cogiendo velocidad y, 
                    a medida que vaya más deprisa, gira y siente como derrapas encima del agua. No te preocupes por si te mojas: estos simpáticos peces no dejarán que te salpique ni una gota.',
                    'C24',
                    '01', 
                    '014')''')

#Mexico '01' 5
cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Hurakan Condor',
                    'Emocionante',
                    12,
                    140,
                    'Ambientada en los restos de una antigua torre azteca repleta de jeroglíficos, esta atracción representa el ritual del sacrificio en honor al dios Hurakan. 
                    Mientras subes, podrás deleitarte con las espectaculares vistas de todo el parque temático y de la costa mediterránea; pero prepárate, porque cuando llegues arriba y menos te lo esperes, 
                    te dejará caer al vacío y notarás una sensación única que solo este dios podrá detener. ¿Confías en él?',
                    'C25',
                    '01', 
                    '015')''')

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('El Diablo - Tren de la Mina',
                    'Moderada',
                    12,
                    140,
                    'A día de hoy, los vagones de madera originales siguen funcionando y el Tren de la Mina circula a toda velocidad por el fascinante recorrido que hacía años atrás cargado 
                    con la plata mexicana que extraían los trabajadores desaparecidos. Ahora es El Diablo quien conduce este tren y quien te llevará por todos los rincones en un viaje en el que tendrás 
                    que estar muy atento a todo lo que veas a tu alrededor. ¿Serás capaz de llegar a lo más profundo sin perderte ni un solo detalle?',
                    'C26',
                    '01', 
                    '015')''') 

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Serpiente Emplumada',
                    'Moderada',
                    10,
                    130,
                    'Un tótem sagrado plagado de extremidades irá cogiendo fuerza mientras la serpiente empieza a girar a su alrededor cada vez más rápido. 
                    Los brazos del tótem te acercarán y alejarán del suelo mientras giran a gran velocidad. 
                    Formarás parte de un ritual único que solo podrás encontrar en esta poderosa atracción del área de México de PortAventura.',
                    'C27',
                    '01', 
                    '015')''')  

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Yucatan',
                    'Moderada',
                    10,
                    140,
                    'Un sonido te avisará de que todo está a punto de empezar. Al principio será un tranquilo paseo, pero a medida que vayas girando, 
                    ganarás velocidad; así que agárrate fuerte e intenta plantarle cara a Yucatan de PortAventura Park.
                    ¡Te avisamos de que no será nada fácil!',
                    'C28',
                    '01', 
                    '015')''')  

# Polynesia '03' 6
cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Tutuki Splash',
                    'Moderada',
                    12,
                    140,
                    'Desafía al volcán a bordo de una barcaza por unas aguas que esconden un sinfín de sorpresas. ¡Bienvenido a una de las atracciones más emocionantes de PortAventura Park!',
                    'C29',
                    '01', 
                    '016')''')  

cursor.execute('''INSERT OR IGNORE INTO Atracciones 
                    VALUES ('Kontiki',
                    'Moderada',
                    12,
                    140,
                    'Únete a la tripulación y agárrate fuerte donde puedas mientras el barco sube y se pone totalmente perpendicular al suelo. 
                    Déjate llevar en cada bajada para que este majestuoso catamarán siga surcando las aguas de la Polinesia Francesa. 
                    Solo los más fuertes superarán la atracción Kontiki. ¿Vas a dejar que te lo cuenten?',
                    'C30',
                    '01', 
                    '016')''')

# %%
# ZONAS - PORT AVENTURA
# Polynesia
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('016',
                    "Hawaiano",
                    "Aloha Tahiti",
                    "Las islas de la Polinesia son conocidas por su belleza, sus playas, sus bailes y su espíritu paradisíaco. 
                    Uno de los espectáculos del área de Polynesia de PortAventura Park más admirados es el espectáculo Aloha Tahití. 
                    ¡Estate atento y no te pierdas ni un detalle!",
                    8)''')
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('016',
                    "Hawaiano",
                    "Pareos en Bora Bora",
                    "Te encuentras en Polynesia y haces una parada para comer y degustar su comida exótica. 
                    Comienza a sonar la música y el escenario se llena de alegría y ritmo. Acompaña tu comida con bailes polinesios. 
                    Algunos se ponen el pareo como una falda y otros se lo atan con un simple nudo al lado",
                    8)''')
# Mexico
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('015',
                    "Mexicana",
                    "Fiesta Mexicana",
                    "En el área temática de México, puedes adentrarte en La Cantina y disfrutar del espectáculo más autóctono de México. 
                    Con una representación cultural que mezcla elementos de diversos períodos, este espectáculo revive tradiciones de todas estas épocas en directo. 
                    La tradición y la modernidad mayas se juntan en este espectáculo para mostrarte su fuerza y belleza ancestral en nuestros días",
                    8)''')
# Sesamo
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('014',
                    "Barrio sesamo",
                    "Abby Star Studio",
                    "Si quieres entrar en el divertido mundo de Abby Cadabby, no te pierdas su estudio ¡y conviértete en una hada de ensueño! En el interior, 
                    podrás vestirte con los preciosos vestidos de Abby (su armario es inmenso), pintarte con su colorido maquillaje lleno de brillibrilli y crear 
                    tu look definitivo",
                    8)''')
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('014',
                    "Barrio sesamo",
                    "Let’s Dance",
                    "Ven, toma asiento y disfruta del espectáculo Let’s Dance, donde Epi, Blas, Elmo, Coco, Abby y Cookie Monster te harán partícipe de su nueva aventura. 
                    Disfruta de esta puesta en escena en la que, además de pasarlo en grande, ¡podrás hacer nuevos amigos",
                    8)''')
# Meditarraneo
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('013',
                    "Mediterranea",
                    "PortAventura Parade",
                    "Camina hacia la salida junto a tus acompañantes mientras recuerdas los mejores momentos del día y, conforme te vayas acercando a Mediterrània, 
                    escucharás una música de fondo… ¡Aún queda más diversión! El paseo del pueblo pesquero de PortAventura Park estará repleto de carrozas, colores y 
                    música, y todo el elenco de artistas acompañará a los iconos del parque: Woody, Epi, Blas, Coco… Un desfile que pondrá fin a un día lleno de emociones",
                    8)''')
# China
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('012',
                    "Oriental",
                    "Magic Bubble",
                    "Nuestro alquimista se lo pasa en grande creando burbujas de todos los tamaños y colores, 
                    desde miles de burbujas hasta la pompa de jabón más grande que hayas visto jamás",
                    8)''')
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('012',
                    "Oriental",
                    "Destination Dance",
                    "El Gran Teatro Imperial de China se viste de gala y te abre las puertas para que disfrutes de un espectáculo lleno de música, ritmo y color. 
                    Un viaje a través del mundo de la danza. Un espectáculo increíble, lleno de bailes, acrobacias y la mejor música. 
                    Tres fantásticas voces e increíbles acróbatas conducirán este espectáculo musical de gran formato",
                    8)''')
# Far west
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('011',
                    "Lejano oeste",
                    "West Gold Frenzy",
                    "En el pueblo de Penitence, en el Lejano Oeste, la población se encuentra aterrorizada por continuos ataques de malvados forajidos. 
                    Ya solo quedan unos pocos residentes valientes: dos banqueros, el incorruptible Sheriff, su torpe ayudante, y dos ciudadanos decididos a proteger 
                    lo que queda de su hogar",
                    8)''')
cursor.execute('''INSERT OR IGNORE INTO Zonas 
                   VALUES ('011',
                    "Lejano oeste",
                    "Can Can Story",
                    "Prepárate para un espectáculo musical sin precedentes. El fantástico cancán se representa en el Long Branch Saloon, un típico 
                    Saloon del lejano Oeste en el que las bailarinas ponen la guinda al pastel. Un formato diferente donde tú serás el protagonista e interactuarás con 
                    los artistas para vivir una auténtica celebración al más puro estilo del lejano Oeste",
                    8)''')

# %%
# ALOJAMIENTO - PORT AVENTURA

cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel Mansión de Lucy",
                    295,
                    "5 estrellas",
                    "150 Habitaciones para familias",
                    "Época Victoriana",
                    "01")''')

cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel Colorado Creek",
                    135,
                    "4 estrellas",
                    "125 Habitaciones para familias",
                    "Far West",
                    "01")''')
cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel Gold River",
                    135,
                    "4 estrellas",
                    "120 Habitaciones para familias",
                    "Far West",
                    "01")''')

cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel PortAventura",
                    135,
                    "4 estrellas",
                    "100 Habitaciones para familias",
                    "Mediterráneo",
                    "01")''')

cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel Caribe",
                    130,
                    "4 estrellas",
                    "125 Habitaciones para familias",
                    "Caribe",
                    "01")''')
cursor.execute('''INSERT OR IGNORE INTO Alojamiento 
                   VALUES ("Hotel El Paso",
                    130,
                    "4 estrellas",
                    "130 Habitaciones para familias",
                    "Mexico",
                    "01")''')

# %%
conn.commit()
conn.close()
